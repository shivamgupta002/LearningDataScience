# %%
import pandas as pd
df=pd.read_csv('../../Data/Iris.csv')
df.head(7)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# convert 3 species into 0, 1, 2
le=LabelEncoder()
df['Species']=le.fit_transform(df['Species'])

# %%
df.sample(10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 65    66            6.7           3.1            4.4           1.4        1
# 126  127            6.2           2.8            4.8           1.8        2
# 8      9            4.4           2.9            1.4           0.2        0
# 138  139            6.0           3.0            4.8           1.8        2
# 132  133            6.4           2.8            5.6           2.2        2
# 89    90            5.5           2.5            4.0           1.3        1
# 107  108            7.3           2.9            6.3           1.8        2
# 143  144            6.8           3.2            5.9           2.3        2
# 31    32            5.4           3.4            1.5           0.4        0
# 21    22            5.1           3.7            1.5           0.4        0

# %%
from sklearn.model_selection import train_test_split
x=df.drop('Species',axis=1)
y=df['Species']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression(max_iter=1000)
lr.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(x_train, y_train)
# Out:
# GaussianNB()

# %% [markdown]
# ## Comparing Models

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

models = {'Logistic Regression': lr, 'KNN': knn, 'Naive Bayes': nb}

for name, model in models.items():
    y_pred = model.predict(x)
    print(f"\n{name}")
    print("Accuracy:", accuracy_score(y, y_pred))
    
    print("Confusion matrix:", confusion_matrix(y, y_pred))

    print("Classification report:", classification_report(y, y_pred))
# Out:
# Logistic Regression
# Accuracy: 1.0
# Confusion matrix: [[50  0  0]
#  [ 0 50  0]
#  [ 0  0 50]]
# Classification report:               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        50
#            1       1.00      1.00      1.00        50
#            2       1.00      1.00      1.00        50
#
#     accuracy                           1.00       150
#    macro avg       1.00      1.00      1.00       150
# weighted avg       1.00      1.00      1.00       150
#
#
# KNN
# Accuracy: 1.0
# Confusion matrix: [[50  0  0]
#  [ 0 50  0]
#  [ 0  0 50]]
# Classification report:               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        50
#            1       1.00      1.00      1.00        50
#            2       1.00      1.00      1.00        50
#
#     accuracy                           1.00       150
#    macro avg       1.00      1.00      1.00       150
# ...

# %%
### Final Answer

# %% [raw]
# 1. Logistic Regression
#
# Accuracy: 1.00
# Errors: 0
# Perfect precision, recall, F1-score (1.00 for all classes)
#
# 2. KNN
#
# Accuracy: 1.00
# Errors: 0
# Perfect precision, recall, F1-score (1.00 for all classes)
#
# 3. Naive Bayes
#
# Accuracy: 0.9933 (99.33%)
# Errors: 1 misclassification
# Slightly lower precision/recall for class 1 and 2
#
#
# 📌 Best Performing Models:
#
# Logistic Regression and KNN (Tie)
# They both:
# Achieved 100% accuracy
# Had zero misclassifications
#
# Perfect precision, recall, and F1-score
#
# 🤔 So Which One Should You Choose?
#
# Even though both are perfect, here’s how you decide:
#
# | Factor                         | Logistic Regression | KNN                                   |
# | ------------------------------ | ------------------- | -----------------------------------   |
# | Speed (Prediction)             | ✅ Very Fast        | ❌ Slower (stores all training data) |
# | Memory Usage                   | ✅ Low              | ❌ Higher                            |
# | Works well with large datasets | ✅ Yes              | ❌ Can be slow                       |
# | Model interpretability         | ✅ Yes              | ❌ No                                |
#
#
# 🎯 Final Recommendation
#
# 👉 Logistic Regression is the best choice
