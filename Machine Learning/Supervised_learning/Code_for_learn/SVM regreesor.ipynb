# %%
from sklearn.svm import SVR
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score,r2_score

# %%
df=datasets.load_diabetes(as_frame=True).frame

# %%
# df.shape
df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3        s4        s5        s6  target
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401 -0.002592  0.019907 -0.017646   151.0
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412 -0.039493 -0.068332 -0.092204    75.0
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356 -0.002592  0.002861 -0.025930   141.0
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038  0.034309  0.022688 -0.009362   206.0
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142 -0.002592 -0.031988 -0.046641   135.0

# %%
x=df.drop("target",axis=1)
y=df["target"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
y_scaler=StandardScaler()

y_train_scaled=y_scaler.fit_transform(y_train.values.reshape(-1,1)).ravel()
y_test_scaled=y_scaler.transform(y_test.values.reshape(-1,1)).ravel()

# %%
### model
model=SVR()
model.fit(x_train,y_train_scaled)
# Out:
# SVR()

# %%
y_test_pred_scaled=model.predict(x_test)
y_train_pred_scaled=model.predict(x_train)

# %%
print("Train r2 score : ",r2_score(y_train_scaled,y_train_pred_scaled))
print("Test r2 score : ",r2_score(y_test_scaled,y_test_pred_scaled))
# Out:
# Train r2 score :  0.6596361676267712
# Test r2 score :  0.48844443151651906

# %%
### Lienar
model=SVR(kernel="linear")
model.fit(x_train,y_train_scaled)
y_test_pred_scaled=model.predict(x_test)
y_train_pred_scaled=model.predict(x_train)
print("Train r2 score : ",r2_score(y_train_scaled,y_train_pred_scaled))
print("Test r2 score : ",r2_score(y_test_scaled,y_test_pred_scaled))
# Out:
# Train r2 score :  0.45191229982475245
# Test r2 score :  0.4433761323833776

# %%
### Polynomial
model=SVR(kernel="poly")
model.fit(x_train,y_train_scaled)
y_test_pred_scaled=model.predict(x_test)
y_train_pred_scaled=model.predict(x_train)
print("Train r2 score : ",r2_score(y_train_scaled,y_train_pred_scaled))
print("Test r2 score : ",r2_score(y_test_scaled,y_test_pred_scaled))
# Out:
# Train r2 score :  0.5790920834310542
# Test r2 score :  0.24203771038107735

# %%
### Sigmoid
model=SVR(kernel="sigmoid")
model.fit(x_train,y_train_scaled)
y_test_pred_scaled=model.predict(x_test)
y_train_pred_scaled=model.predict(x_train)
print("Train r2 score : ",r2_score(y_train_scaled,y_train_pred_scaled))
print("Test r2 score : ",r2_score(y_test_scaled,y_test_pred_scaled))
# Out:
# Train r2 score :  -19.72119344073131
# Test r2 score :  -15.316808189576822

# %% [markdown]
# ## Hyperparmeter tuing using GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid={
    "C" :[1,2,5,10,100],
    "kernel" :["rbf","linear"],
    "epsilon":[0.01,0.1,0.2,0.4]
}

# %%
svr=SVR()

grid_search=GridSearchCV(svr, param_grid, scoring="r2", cv=5)
grid_search.fit(x_train,y_train_scaled)
# Out:
# GridSearchCV(cv=5, estimator=SVR(),
#              param_grid={'C': [1, 2, 5, 10, 100],
#                          'epsilon': [0.01, 0.1, 0.2, 0.4],
#                          'kernel': ['rbf', 'linear']},
#              scoring='r2')

# %%
print(f"Best params for SVR is : {grid_search.best_estimator_} ")
# Out:
# Best params for SVR is : SVR(C=10, kernel='linear')

# %%
best_model=SVR(C=10, kernel='linear',epsilon=0.1)
best_model.fit(x_train,y_train_scaled)
y_test_pred_scaled=best_model.predict(x_test)
y_train_pred_scaled=best_model.predict(x_train)
print("Train r2 score : ",r2_score(y_train_scaled,y_train_pred_scaled))
print("Test r2 score : ",r2_score(y_test_scaled,y_test_pred_scaled))
# Out:
# Train r2 score :  0.5151066486918875
# Test r2 score :  0.47444183250401095

# %% [markdown]
# ## Linear SVR

# %%
from sklearn.svm import LinearSVR

model=LinearSVR(C=10,epsilon=0.1,max_iter=5000)
model.fit(x_train,y_train_scaled)
y_test_pred_scaled=model.predict(x_test)
y_train_pred_scaled=model.predict(x_train)
print("Train r2 score : ",r2_score(y_train_scaled,y_train_pred_scaled))
print("Test r2 score : ",r2_score(y_test_scaled,y_test_pred_scaled))
# Out:
# Train r2 score :  0.514984426762567
# Test r2 score :  0.47330172090888
